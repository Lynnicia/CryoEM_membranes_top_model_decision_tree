# %%
# !wget -O 640-YOLOv11-LD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-YOLOv11-LD/640-YOLOv11-LD.pt

# %%
# !wget -O 1024-YOLOv11-LD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-YOLOv11-LD/1024-YOLOv11-LD.pt

# %%
# !wget -O 640-YOLOv11-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-YOLOv11-ULD/640-YOLOv11-ULD.pt

# %%
# !wget -O 1024-YOLOv11-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-YOLOv11-ULD/1024-YOLOv11-ULD.pt

# %%
# !wget -O 640-YOLO26-LD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-YOLO26-LD/640-YOLO26-LD.pt

# %%
# !wget -O 1024-YOLO26-LD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-YOLO26-LD/1024-YOLO26-LD.pt

# %%
# !wget -O 640-YOLO26-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-YOLO26-ULD/640-YOLO26-ULD.pt

# %%
# !wget -O 1024-YOLO26-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-YOLO26-ULD/1024-YOLO26-ULD.pt

# %%
# !wget -O 640-U-Net-LD.pt \
https://github.com/Sireesiru/Semantic-Segmentation-of-bacterial-cell-envelope-using-U-Nets/releases/download/v1.0.0/best_unet_dice.pt
#https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-U-Net-LD/640-U-Net-LD.pt

# %%
# !wget -O 1024-U-Net-LD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-U-Net-LD/1024-U-Net-LD.pt

# %%
# !wget -O 640-U-Net-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-U-Net-ULD/640-U-Net-ULD.pt

# %%
# !wget -O 1024-U-Net-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-U-Net-ULD/1024-U-Net-ULD.pt

# %%
# !wget -O 640-Detectron2-LD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-Detectron2-LD/640-Detectron2-LD.pth

# %%
# !wget -O 1024-Detectron2-LD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-Detectron2-LD/1024-Detectron2-LD.pth

# %%
# !wget -O 640-Detectron2-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/640-Detectron2-ULD/640-Detectron2-ULD.pth

# %%
# !wget -O 1024-Detectron2-ULD.pt \
https://github.com/Lynnicia/CryoEM_membranes_top_model_decision_tree/releases/download/1024-Detectron2-ULD/1024-Detectron2-ULD.pth

# %%
# !wget -O 640-SAM3-LD.pt \
https://huggingface.co/LynnMass/640-SAM3-LD/blob/main/640-SAM3-LD.pt

# %%
# !wget -O 1024-SAM3-LD.pt \
https://huggingface.co/LynnMass/1024-SAM3-LD/blob/main/1024-SAM3-LD.pt

# %%
# !wget -O 640-SAM3-ULD.pt \
https://huggingface.co/LynnMass/640-SAM3-ULD/blob/main/640-SAM3-ULD.pt

# %%
# !wget -O 1024-SAM3-ULD.pt \
https://huggingface.co/LynnMass/1024-SAM3-ULD/blob/main/1024-SAM3-ULD.pt
